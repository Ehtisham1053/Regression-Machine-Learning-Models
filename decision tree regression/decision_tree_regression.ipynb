# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Salary_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.columns = ["A" ,"B"]

# %%
df.isnull().sum()
# Out:
# A    0
# B    0
# dtype: int64

# %%
x = df['A']
y = df['B']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (24,)
# (6,)
# (24,)
# (6,)

# %%
# prompt: generate the decision tree regression model and train , test the data set and return the report , also plot the plot_tree

import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import tree

# Create and train the Decision Tree Regression model
model = DecisionTreeRegressor()
model.fit(x_train.values.reshape(-1, 1), y_train)

# Make predictions on the test set
y_pred = model.predict(x_test.values.reshape(-1, 1))

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared: accuracy ", r2*100)

# Plot the decision tree
plt.figure(figsize=(70, 70))
tree.plot_tree(model, filled=True)
plt.savefig('decision_tree.png')
plt.show()
# Out:
# Mean Squared Error: 101047709.83333333
# R-squared: accuracy  80.21759743735161
